# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
import tweepy

# %%
# creds: replace with your Twitter Developer credentials 
con_key = "dwN3COWE9sVlEjW4EEzYjdDFG"
con_sec = "6dyciY4o7TKZ7QDGyORMbVKbR8ouBpfTGdce2ZltTzdmTnOLow"
acc_tok = "1590561174319292416-HsVNJvKg2hzXi9aoL8reCBdLBTqCy5"
acc_sec = "UQVUiQcYvkiw10ASkv4J7IEyALvTt8O0yzy13SQnRM5yQ"

auth = tweepy.OAuthHandler(con_key, con_sec) # authenticate 
auth.set_access_token(acc_tok, acc_sec) # grant access 
api = tweepy.API(auth) # connect to API

# %%
api.update_status("Bot's 1st hello. Thanks tweepy!🐥")
# Out:
# Status(_api=<tweepy.api.API object at 0x7fc5651037f0>, _json={'created_at': 'Wed Nov 16 07:01:00 +0000 2022', 'id': 1592774720922869760, 'id_str': '1592774720922869760', 'text': "Bot's 1st hello. Thanks tweepy!🐥", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://twitter.com" rel="nofollow">Temporal Classification</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1590561174319292416, 'id_str': '1590561174319292416', 'name': 'Gian Carlo Baldonado', 'screen_name': 'baldonado_gian', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 1, 'listed_count': 0, 'created_at': 'Thu Nov 10 04:25:21 +0000 2022', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, '
# ...

# %%
public_tweets = api.home_timeline()

# %%
for t in public_tweets:
    print(t.user.screen_name, t.text)
# Out:
# baldonado_gian Bot's 1st hello. Thanks tweepy!🐥
# baldonado_gian Bot's 1st tweet. Thanks tweepy!🐥
# UCSFHospitals About 70 million Americans have chronic sleep disorders, and UCSF's @AricPrather is here to help with a new book Th… https://t.co/shI3hSWK9E
# UCSFHospitals Using a neuroprosthetic device from UCSF, a paralyzed man who lost the ability to speak can now spell out more than… https://t.co/iRXfrRyxnX
# UCSFHospitals Congratulations to @UCSFCancer's Dr. Alan Venook on his 2022 Luminary Award! Dr. Venook is being recognized for his… https://t.co/jiUGqB44DB
# UCSFHospitals A new tool uses factors like age, sex, smoking status &amp; disease to estimate life expectancy for #dementia patients,… https://t.co/TAcWwJtJ3p
# UCSFHospitals RT @CMangurian: Last day @AAMCtoday #AAMC22.  Have loved seeing old friends and colleagues and making new ones!  Missing selfies with @amy_…
# UCSFHospitals RT @WBerriganMD: Great team today at the #Berkeleyhalfmarathon
#
# ...

# %%
opioid_variants = "oxycontin oxicontin oxcotin oycotin oxycotins oycontin oxycontins oxycoton oxicotin ocycotin oxycodin oxycottin oxycotine ocycontin oxycintin oycotine oxcycontin roxicontin oxycotin oxycontine roxycontin oxycotton oxycottin oxycoton percocet percocet10 perocets percosets percacet percocetes percet pecocet percacets perocet percoct percocets pecocets percoet percocit percocoet percot percoset percecet percicet dilaudid dialudid dilaudad diluadid diaudid dilaudin dilauded dilauid dillaudid dilaudids dulaudid diludid diladid dialaudid dilaudud dalaudid dilautid dilaud dilladid tramadol trammadol tramadal tramal tramdol tramadols tramado tramedol tramadoll tramadole tramidol tamadol tranadol tramodol tremadol tramamdol demmies ultram ultam ultramer percodan oxycodone oxycodons oycondone oycodone oxycodine roxicodone oxicodone oxycoton ocycodone oxcycodone oxycodne oxycodones oxycodin oyxcodone roxycodone oxcodone oxycondone oxycoden oxycodon oxyxodone oxycodene hydromorphone hydromorphine duramorph  fentanyl fentanly fentayl fentynyl fentonyl fentanayl fentanal fentnayl fentany fentenyl fental fentyl fenanyl fentinyl fentnyl fentanl fetanyl fentnyal fentanyal fentanol meperidine vicodin vicoden vycodin fizzies narcan  oxymorphone   hydros amidone morphine morphin morpheine morhphine moraphine diamorphine mophine morephine morhine morphone morhpine morphiene moriphine morpine morphene morphones morphein morophine morphines demerol demarol demorol depomedrol demeral dolophine   codeine codiene codeine coedine codine codene codein heroin herroine heroins heroine heorin herion methadone methadones methadose methodone mehtadone metadone methadon 357s 512s o bomb big h black tar brown sugar captain cody china girl china white "
opioid_list = opioid_variants.split(" ")
op = " OR ".join(opioid_list)
op = 'oxycontin OR oxicontin OR oxcotin OR oycotin OR oxycotins OR oycontin OR oxycontins OR oxycoton OR oxicotin OR ocycotin OR oxycodin OR oxycottin OR oxycotine OR ocycontin OR oxycintin OR oycotine OR oxcycontin OR roxicontin OR oxycotin OR oxycontine OR roxycontin OR oxycotton OR oxycottin OR oxycoton OR percocet OR percocet10 OR perocets OR percosets OR percacet OR percocetes OR percet OR pecocet OR percacets OR perocet OR percoct OR percocets OR pecocets OR percoet OR percocit OR percocoet OR percot OR percoset OR percecet OR percicet OR dilaudid OR dialudid OR dilaudad OR diluadid OR diaudid OR dilaudin OR dilauded OR dilauid OR dillaudid OR dilaudids OR dulaudid OR diludid OR diladid OR dialaudid OR dilaudud OR dalaudid OR dilautid OR dilaud OR dilladid OR tramadol OR trammadol OR tramadal OR tramal OR tramdol OR tramadols OR tramado OR tramedol OR tramadoll OR tramadole OR tramidol OR tamadol OR tranadol OR tramodol OR tremadol OR tramamdol OR demmies OR ultram OR ultam OR ultramer OR percodan OR oxycodone OR oxycodons OR oycondone OR oycodone OR oxycodine OR roxicodone OR oxicodone OR oxycoton OR ocycodone OR oxcycodone OR oxycodne OR oxycodones OR oxycodin OR oyxcodone OR roxycodone OR oxcodone OR oxycondone OR oxycoden OR oxycodon OR oxyxodone OR oxycodene OR hydromorphone OR hydromorphine OR duramorph OR  OR fentanyl OR fentanly OR fentayl OR fentynyl OR fentonyl OR fentanayl OR fentanal OR fentnayl OR fentany OR fentenyl OR fental OR fentyl OR fenanyl OR fentinyl OR fentnyl OR fentanl OR fetanyl OR fentnyal OR fentanyal OR fentanol OR meperidine OR vicodin OR vicoden OR vycodin OR fizzies OR narcan OR  OR oxymorphone OR  OR  OR hydros OR amidone OR morphine OR morphin OR morpheine OR morhphine OR moraphine OR diamorphine OR mophine OR morephine OR morhine OR morphone OR morhpine OR morphiene OR moriphine OR morpine OR morphene OR morphones OR morphein OR morophine OR morphines OR demerol OR demarol OR demorol OR depomedrol OR demeral OR dolophine OR  OR  OR codeine OR codiene OR codeine OR coedine OR codine OR codene OR codein OR heroin OR herroine OR heroins OR heroine OR heorin OR herion OR methadone OR methadones OR methadose OR methodone OR mehtadone OR metadone OR methadon OR 357s OR 512s o bomb OR big h OR black tar OR brown sugar OR captain cody OR china girl OR china white OR chiva OR doors & fours OR hell dust OR mexican brown OR miss emma OR murder 8 OR negra OR norco OR opana OR oxy OR oxy 80s OR oxycet OR oxys OR percs OR purple drank OR sizzurp OR skag OR tango and cash OR vicos OR vics OR vike OR watson-387 OR white horse'
a = "chiva doors & hell dust mexican brown miss emma murder 8 negra norco opana oxy oxy 80s oxycet oxys percs purple drank sizzurp skag tango and cash vicos vics vike watson white horse"
a= a.split(" ")
a = " OR ".join(a)
a = 'chiva OR doors & fours OR hell dust OR mexican brown OR miss emma OR murder 8 OR negra OR norco OR opana OR oxy OR oxy 80s OR oxycet OR oxys OR percs OR purple drank OR sizzurp OR skag OR tango and cash OR vicos OR vics OR vike OR watson-387 OR white horse'
op_final = """oxycontin OR oxicontin OR oxcotin OR oycotin OR oxycotins OR oycontin OR oxycontins OR oxycoton OR oxicotin OR ocycotin OR oxycodin OR oxycottin OR oxycotine OR ocycontin OR oxycintin OR oycotine OR oxcycontin OR roxicontin OR oxycotin OR oxycontine OR roxycontin OR oxycotton OR oxycottin OR oxycoton OR percocet OR percocet10 OR perocets OR percosets OR percacet OR percocetes OR percet OR pecocet OR percacets OR perocet OR percoct OR percocets OR pecocets OR percoet OR percocit OR percocoet OR percot OR percoset OR percecet OR percicet OR dilaudid OR dialudid OR dilaudad OR diluadid OR diaudid OR dilaudin OR dilauded OR dilauid OR dillaudid OR dilaudids OR dulaudid OR diludid OR diladid OR dialaudid OR dilaudud OR dalaudid OR dilautid OR dilaud OR dilladid OR tramadol OR trammadol OR tramadal OR tramal OR tramdol OR tramadols OR tramado OR tramedol OR tramadoll OR tramadole OR tramidol OR tamadol OR tranadol OR tramodol OR tremadol OR tramamdol OR demmies OR ultram OR ultam OR ultramer OR percodan OR oxycodone OR oxycodons OR oycondone OR oycodone OR oxycodine OR roxicodone OR oxicodone OR oxycoton OR ocycodone OR oxcycodone OR oxycodne OR oxycodones OR oxycodin OR oyxcodone OR roxycodone OR oxcodone OR oxycondone OR oxycoden OR oxycodon OR oxyxodone OR oxycodene OR hydromorphone OR hydromorphine OR duramorph OR fentanyl OR fentanly OR fentayl OR fentynyl OR fentonyl OR fentanayl OR fentanal OR fentnayl OR fentany OR fentenyl OR fental OR fentyl OR fenanyl OR fentinyl OR fentnyl OR fentanl OR fetanyl OR fentnyal OR fentanyal OR fentanol OR meperidine OR vicodin OR vicoden OR vycodin OR fizzies OR narcan OR oxymorphone OR hydros OR amidone OR morphine OR morphin OR morpheine OR morhphine OR moraphine OR diamorphine OR mophine OR morephine OR morhine OR morphone OR morhpine OR morphiene OR moriphine OR morpine OR morphene OR morphones OR morphein OR morophine OR morphines OR demerol OR demarol OR demorol OR depomedrol OR demeral OR dolophine OR codeine OR codiene OR codeine OR coedine OR codine OR codene OR codein OR heroin OR herroine OR heroins OR heroine OR heorin OR herion OR methadone OR methadones OR methadose OR methodone OR mehtadone OR metadone OR methadon OR 357s OR 512s o bomb OR "big h" OR black tar OR brown sugar OR "captain cody" OR china girl OR china white OR chiva OR doors & fours OR hell dust OR mexican brown OR miss emma OR murder 8 OR negra OR norco OR opana OR oxy OR oxy 80s OR oxycet OR oxys OR percs OR purple drank OR sizzurp OR skag OR tango and cash OR vicos OR vics OR vike OR watson-387 OR white horse"""
op_final
# Out:
# 'oxycontin OR oxicontin OR oxcotin OR oycotin OR oxycotins OR oycontin OR oxycontins OR oxycoton OR oxicotin OR ocycotin OR oxycodin OR oxycottin OR oxycotine OR ocycontin OR oxycintin OR oycotine OR oxcycontin OR roxicontin OR oxycotin OR oxycontine OR roxycontin OR oxycotton OR oxycottin OR oxycoton OR percocet OR percocet10 OR perocets OR percosets OR percacet OR percocetes OR percet OR pecocet OR percacets OR perocet OR percoct OR percocets OR pecocets OR percoet OR percocit OR percocoet OR percot OR percoset OR percecet OR percicet OR dilaudid OR dialudid OR dilaudad OR diluadid OR diaudid OR dilaudin OR dilauded OR dilauid OR dillaudid OR dilaudids OR dulaudid OR diludid OR diladid OR dialaudid OR dilaudud OR dalaudid OR dilautid OR dilaud OR dilladid OR tramadol OR trammadol OR tramadal OR tramal OR tramdol OR tramadols OR tramado OR tramedol OR tramadoll OR tramadole OR tramidol OR tamadol OR tranadol OR tramodol OR tremadol OR tramamdol OR demmies OR ultram OR ultam OR ultra
# ...

# %%
opioid_list = np.array(opioid_list)

opioid_list
# Out:
# array(['oxycontin', 'oxicontin', 'oxcotin', 'oycotin', 'oxycotins',
#        'oycontin', 'oxycontins', 'oxycoton', 'oxicotin', 'ocycotin',
#        'oxycodin', 'oxycottin', 'oxycotine', 'ocycontin', 'oxycintin',
#        'oycotine', 'oxcycontin', 'roxicontin', 'oxycotin', 'oxycontine',
#        'roxycontin', 'oxycotton', 'oxycottin', 'oxycoton', 'percocet',
#        'percocet10', 'perocets', 'percosets', 'percacet', 'percocetes',
#        'percet', 'pecocet', 'percacets', 'perocet', 'percoct',
#        'percocets', 'pecocets', 'percoet', 'percocit', 'percocoet',
#        'percot', 'percoset', 'percecet', 'percicet', 'dilaudid',
#        'dialudid', 'dilaudad', 'diluadid', 'diaudid', 'dilaudin',
#        'dilauded', 'dilauid', 'dillaudid', 'dilaudids', 'dulaudid',
#        'diludid', 'diladid', 'dialaudid', 'dilaudud', 'dalaudid',
#        'dilautid', 'dilaud', 'dilladid', 'tramadol', 'trammadol',
#        'tramadal', 'tramal', 'tramdol', 'tramadols', 'tramado',
# ...

# %%
opioid_list_split = np.array_split(opioid_list, 30)
opioid_list_split

opioid_list_split = [" OR ".join(opioid_list_split[i]) for i in range(0, len(opioid_list_split))]
opioid_list_split
# Out:
# ['oxycontin OR oxicontin OR oxcotin OR oycotin OR oxycotins OR oycontin OR oxycontins',
#  'oxycoton OR oxicotin OR ocycotin OR oxycodin OR oxycottin OR oxycotine OR ocycontin',
#  'oxycintin OR oycotine OR oxcycontin OR roxicontin OR oxycotin OR oxycontine OR roxycontin',
#  'oxycotton OR oxycottin OR oxycoton OR percocet OR percocet10 OR perocets OR percosets',
#  'percacet OR percocetes OR percet OR pecocet OR percacets OR perocet OR percoct',
#  'percocets OR pecocets OR percoet OR percocit OR percocoet OR percot OR percoset',
#  'percecet OR percicet OR dilaudid OR dialudid OR dilaudad OR diluadid OR diaudid',
#  'dilaudin OR dilauded OR dilauid OR dillaudid OR dilaudids OR dulaudid OR diludid',
#  'diladid OR dialaudid OR dilaudud OR dalaudid OR dilautid OR dilaud OR dilladid',
#  'tramadol OR trammadol OR tramadal OR tramal OR tramdol OR tramadols OR tramado',
#  'tramedol OR tramadoll OR tramadole OR tramidol OR tamadol OR tranadol OR tramodol',
# ...

# %%
opioid_list_split[-1][0].replace('h', "'big h'")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/cz/vjt5grr94cn0qr63v4qx4qth0000gn/T/ipykernel_14494/34789128.py in <module>
# ----> 1 opioid_list_split[-1][0] = opioid_list_split[-1][0].replace('h', "'big h'")
#
# TypeError: 'str' object does not support item assignment

# %%
opioid_list_split
# Out:
# ['oxycontin OR oxicontin OR oxcotin OR oycotin OR oxycotins OR oycontin OR oxycontins OR oxycoton OR oxicotin',
#  'ocycotin OR oxycodin OR oxycottin OR oxycotine OR ocycontin OR oxycintin OR oycotine OR oxcycontin OR roxicontin',
#  'oxycotin OR oxycontine OR roxycontin OR oxycotton OR oxycottin OR oxycoton OR percocet OR percocet10 OR perocets',
#  'percosets OR percacet OR percocetes OR percet OR pecocet OR percacets OR perocet OR percoct OR percocets',
#  'pecocets OR percoet OR percocit OR percocoet OR percot OR percoset OR percecet OR percicet OR dilaudid',
#  'dialudid OR dilaudad OR diluadid OR diaudid OR dilaudin OR dilauded OR dilauid OR dillaudid',
#  'dilaudids OR dulaudid OR diludid OR diladid OR dialaudid OR dilaudud OR dalaudid OR dilautid',
#  'dilaud OR dilladid OR tramadol OR trammadol OR tramadal OR tramal OR tramdol OR tramadols',
#  'tramado OR tramedol OR tramadoll OR tramadole OR tramidol OR tamadol OR tranadol OR tramodol',
# ...

# %%
opioids = ['oxycontin OR oxicontin OR oxcotin OR oycotin OR oxycotins OR oycontin OR oxycontins OR oxycoton OR oxicotin',
 'ocycotin OR oxycodin OR oxycottin OR oxycotine OR ocycontin OR oxycintin OR oycotine OR oxcycontin OR roxicontin',
 'oxycotin OR oxycontine OR roxycontin OR oxycotton OR oxycottin OR oxycoton OR percocet OR percocet10 OR perocets',
 'percosets OR percacet OR percocetes OR percet OR pecocet OR percacets OR perocet OR percoct OR percocets',
 'pecocets OR percoet OR percocit OR percocoet OR percot OR percoset OR percecet OR percicet OR dilaudid',
 'dialudid OR dilaudad OR diluadid OR diaudid OR dilaudin OR dilauded OR dilauid OR dillaudid',
 'dilaudids OR dulaudid OR diludid OR diladid OR dialaudid OR dilaudud OR dalaudid OR dilautid',
 'dilaud OR dilladid OR tramadol OR trammadol OR tramadal OR tramal OR tramdol OR tramadols',
 'tramado OR tramedol OR tramadoll OR tramadole OR tramidol OR tamadol OR tranadol OR tramodol',
 'tremadol OR tramamdol OR demmies OR ultram OR ultam OR ultramer OR percodan OR oxycodone',
 'oxycodons OR oycondone OR oycodone OR oxycodine OR roxicodone OR oxicodone OR oxycoton OR ocycodone',
 'oxcycodone OR oxycodne OR oxycodones OR oxycodin OR oyxcodone OR roxycodone OR oxcodone OR oxycondone',
 'oxycoden OR oxycodon OR oxyxodone OR oxycodene OR hydromorphone OR hydromorphine OR duramorph OR ',
 'fentanyl OR fentanly OR fentayl OR fentynyl OR fentonyl OR fentanayl OR fentanal OR fentnayl',
 'fentany OR fentenyl OR fental OR fentyl OR fenanyl OR fentinyl OR fentnyl OR fentanl',
 'fetanyl OR fentnyal OR fentanyal OR fentanol OR meperidine OR vicodin OR vicoden OR vycodin',
 'fizzies OR narcan OR  OR oxymorphone OR  OR  OR hydros OR amidone',
 'morphine OR morphin OR morpheine OR morhphine OR moraphine OR diamorphine OR mophine OR morephine',
 'morhine OR morphone OR morhpine OR morphiene OR moriphine OR morpine OR morphene OR morphones',
 'morphein OR morophine OR morphines OR demerol OR demarol OR demorol OR depomedrol OR demeral',
 'dolophine OR  OR  OR codeine OR codiene OR codeine OR coedine OR codine',
 'codene OR codein OR heroin OR herroine OR heroins OR heroine OR heorin OR herion',
 'methadone OR methadones OR methadose OR methodone OR mehtadone OR metadone OR methadon OR 357s',
 '512s OR bomb OR "big h" OR "black tar"',
 '"captain cody" OR "china girl" OR "china white"']

# %%
opioids = ['oxycontin OR oxicontin OR oxcotin OR oycotin OR oxycotins OR oycontin OR oxycontins',
 'oxycoton OR oxicotin OR ocycotin OR oxycodin OR oxycottin OR oxycotine OR ocycontin',
 'oxycintin OR oycotine OR oxcycontin OR roxicontin OR oxycotin OR oxycontine OR roxycontin',
 'oxycotton OR oxycottin OR oxycoton OR percocet OR percocet10 OR perocets OR percosets',
 'percacet OR percocetes OR percet OR pecocet OR percacets OR perocet OR percoct',
 'percocets OR pecocets OR percoet OR percocit OR percocoet OR percot OR percoset',
 'percecet OR percicet OR dilaudid OR dialudid OR dilaudad OR diluadid OR diaudid',
 'dilaudin OR dilauded OR dilauid OR dillaudid OR dilaudids OR dulaudid OR diludid',
 'diladid OR dialaudid OR dilaudud OR dalaudid OR dilautid OR dilaud OR dilladid',
 'tramadol OR trammadol OR tramadal OR tramal OR tramdol OR tramadols OR tramado',
 'tramedol OR tramadoll OR tramadole OR tramidol OR tamadol OR tranadol OR tramodol',
 'tremadol OR tramamdol OR demmies OR ultram OR ultam OR ultramer OR percodan',
 'oxycodone OR oxycodons OR oycondone OR oycodone OR oxycodine OR roxicodone OR oxicodone',
 'oxycoton OR ocycodone OR oxcycodone OR oxycodne OR oxycodones OR oxycodin OR oyxcodone',
 'roxycodone OR oxcodone OR oxycondone OR oxycoden OR oxycodon OR oxyxodone OR oxycodene',
 'hydromorphone OR hydromorphine OR duramorph OR  OR fentanyl OR fentanly OR fentayl',
 'fentynyl OR fentonyl OR fentanayl OR fentanal OR fentnayl OR fentany OR fentenyl',
 'fental OR fentyl OR fenanyl OR fentinyl OR fentnyl OR fentanl OR fetanyl',
 'fentnyal OR fentanyal OR fentanol OR meperidine OR vicodin OR vicoden OR vycodin',
 'fizzies OR narcan OR  OR oxymorphone OR  OR  OR hydros',
 'amidone OR morphine OR morphin OR morpheine OR morhphine OR moraphine OR diamorphine',
 'mophine OR morephine OR morhine OR morphone OR morhpine OR morphiene OR moriphine',
 'morpine OR morphene OR morphones OR morphein OR morophine OR morphines OR demerol',
 'demarol OR demorol OR depomedrol OR demeral OR dolophine OR  OR ',
 'codeine OR codiene OR codeine OR coedine OR codine OR codene OR codein',
 'heroin OR herroine OR heroins OR heroine OR heorin OR herion',
 'methadone OR methadones OR methadose OR methodone OR mehtadone OR metadone',
 'methadon OR 357s OR 512s OR bomb OR "big h"',
 '"black tar"',
 '"captain cody" OR "china girl" OR "china white"']

# %%
extras = "(sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose) -RT exclude:mentions exclude:replies -has:links"

# %%
opioids = [ "(" + i + ") " + extras for i in opioids]

# %%
opioids
# Out:
# ['(oxycontin OR oxicontin OR oxcotin OR oycotin OR oxycotins OR oycontin OR oxycontins) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose) -RT exclude:mentions exclude:replies -has:links',
#  '(oxycoton OR oxicotin OR ocycotin OR oxycodin OR oxycottin OR oxycotine OR ocycontin) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose) -RT exclude:mentions exclude:replies -has:links',
#  '(oxycintin OR oycotine OR oxcycontin OR roxicontin OR oxycotin OR oxycontine OR roxycontin) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose) -RT exclude:mentions exclude:replies -has:links',
#  '(oxycotton OR oxycottin OR oxycoton OR percocet OR percocet10 OR perocets OR percosets) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose) -RT exclude:mentions exclude:replies -has:links',
# ...

# %%
keys_1 = "opioid, alprazolam, amphetamine, antidepressant, benzodiazepine, buprenorphine, cocaine, diazepam, fentanyl, heroin, hydrocodone, meth, methadone, morphine, naloxone, narcan, opana, opiate, overdose, oxycodone, oxymorphone, percocet, suboxone, subutex, pill, rehab, sober, withdrawal -RT"
keys_1 = keys_1.split(", ")
keys_1 = " OR ".join(keys_1
keys_1

# %%
# Complete

oxy = "(oxycontin OR oxicontin OR oxcotin OR oycotin OR oxycotins OR oycontin OR oxycontins OR oxycoton OR oxicotin ) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover)  -RT exclude:mentions exclude:replies -has:links"
per = "(percocet OR percocet10 OR perocets OR percosets OR percacet OR percocetes OR percet OR pecocet OR percacets OR perocet OR percoct OR percocets) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
dil = "(dilaudid OR dialudid OR dilaudad OR diluadid OR diaudid OR dilaudin OR dilauded OR dilauid OR dillaudid OR dilaudids OR dulaudid OR diludid OR diladid OR dialaudid ) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
tra = "(tramadol OR trammadol OR tramadal OR tramal OR tramdol OR tramadols OR tramado OR tramedol OR tramadoll OR tramadole OR tramidol OR tamadol OR demmies OR ultram) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
cod = "(percodan OR oxycodone OR oxycodons OR oycondone OR oycodone OR oxycodine OR roxicodone OR oxicodone OR oxycoton OR ocycodone OR oxcycodone OR oxycodne OR oxycodones OR oxycodin) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
fen = "(hydromorphone OR hydromorphine OR duramorph OR fentanyl OR fentanly OR fentayl OR fentynyl OR fentonyl OR fentanayl OR fentanal OR fentnayl OR fentany OR fentenyl OR fental OR fentyl OR fenanyl ) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
dem = "(meperidine OR vicodin OR vicoden OR vycodin OR fizzies OR narcan OR oxymorphone OR hydros OR amidone OR morphine OR morphin OR morpheine OR morhphine OR morhpine OR morophine OR morphines OR demerol OR demarol OR demorol OR depomedrol OR demeral) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
met = "(dolophine OR codeine OR codiene OR codeine OR coedine OR codine OR codene OR codein OR heroin OR herroine OR heroins OR heroine OR heorin OR herion OR methadone OR methadones OR methadose OR methodone OR mehtadone OR metadone OR methadon) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
big = "'big h' (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
bla = "'black tar' (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
bro = "'brown sugar' (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
cha = "'captain cody' (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
chi = "chiva OR negra OR norco OR opana (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
dor = "'door & fours' (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
mex = "'mexican brown' (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
# mis = "i miss emma -RT exclude:mentions exclude:replies -has:links"
# mur = "i murder 8 -RT exclude:mentions exclude:replies -has:links"
# hel = "i 'hell dust' -RT exclude:mentions exclude:replies -has:links"
oxs = "'oxy 80s' (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
pur = "purple drank (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
tan = "'tango and cash' (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
wat = "'watson-387' (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
whi = "'white horse' (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
vic = "oxy OR oxycet OR oxys OR percs OR skag OR vicos OR vics OR vike (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
adi = "medication OR addicted opiod OR misuse OR overdose OR heroin OR fentanyl OR codeine OR percs OR morphine OR oxy OR oxycontin OR methadone OR naloxone (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
keys_1 = '(opioid OR alprazolam OR amphetamine OR antidepressant OR hydros OR "big h" OR "black tar" OR benzodiazepine OR buprenorphine OR cocaine OR diazepam OR fentanyl OR heroin OR hydrocodone OR meth OR methadone OR morphine OR naloxone OR narcan OR opana OR opiate) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links'

# %%
# Shortened

oxy1 = "(oxycontin OR oxicontin OR oxcotin OR oycotin OR oxycotins OR oycontin OR oxycontins OR oxycoton OR oxicotin ) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover)  -RT exclude:mentions exclude:replies -has:links"
per1 = "(percocet OR percocet10 OR perocets OR percosets OR percacet OR percocetes OR percet OR pecocet OR percacets OR perocet OR percoct OR percocets) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
dil1 = "(dilaudid OR dialudid OR dilaudad OR diluadid OR diaudid OR dilaudin OR dilauded OR dilauid) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
dil2 = "(dillaudid OR dilaudids OR dulaudid OR diludid OR diladid OR dialaudid (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
tra1 = "(tramadol OR trammadol OR tramadal OR tramal OR tramdol OR tramadols OR tramado) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
tra2 = "(tramedol OR tramadoll OR tramadole OR tramidol OR tamadol OR demmies OR ultram (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
cod1 = "(percodan OR oxycodone OR oxycodons OR oycondone OR oycodone OR oxycodine OR roxicodone OR oxicodone OR oxycoton) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
fen1 = "(hydromorphone OR fentanyl OR fentanly OR fentayl OR fentynyl OR fentonyl OR fentanayl OR fentanal OR fentnayl OR fentany  ) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
dem1 = "(meperidine OR vicodin OR vicoden OR vycodin OR fizzies (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
dem2 = "(narcan hydros OR amidone OR morphine OR morphin OR morpheine OR morhphine OR morhpine OR morophine OR morphines OR demerol ) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
met1 = "(dolophine OR codeine OR codiene heorin OR herion (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
met2 = "(methadone OR methadones OR methadose OR methodone OR mehtadone OR metadone OR methadon) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
big1 = "'big h' (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover OR fentenyl OR fental OR fentyl OR fenanyl) -RT exclude:mentions exclude:replies -has:links"
bla1 = "'black tar' (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
bro1 = "'brown sugar' (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
cha1 = "'captain cody' (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
chi1 = "chiva OR negra OR norco OR opana (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
dor1 = "'door & fours' (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
mex1 = "'mexican brown' (OR codeine OR coedine OR codine OR codene OR codein OR heroin OR herroine OR heroins OR heroine OR)  (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
# mis = "i miss emma -RT exclude:mentions exclude:replies -has:links"
# mur = "i murder 8 -RT exclude:mentions exclude:replies -has:links"
# hel = "i 'hell dust' -RT exclude:mentions exclude:replies -has:links"
oxs1 = "'oxy 80s' (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
pur1 = "purple drank (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
tan1 = "'tango and cash' (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
wat1 = "'watson-387' (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
whi1 = "'white horse' (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
vic1 = "oxy OR oxycet OR oxys OR percs OR skag OR vicos OR vics OR vike (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
adi1 = "medication OR addicted opiod OR misuse OR overdose OR heroin OR fentanyl OR codeine OR percs OR morphine OR oxy OR oxycontin OR methadone OR naloxone (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links"
keys1 = '(opioid OR alprazolam OR  OR "big h" OR "black tar" OR benzodiazepine OR buprenorphine OR cocaine) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links'
keys2 = '(diazepam OR fentanyl OR heroin OR hydrocodone OR meth OR methadone OR morphine OR naloxone OR narcan OR opana OR opiate amphetamine OR antidepressant OR hydros) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose OR misuse OR recovery OR recover) -RT exclude:mentions exclude:replies -has:links'

# %%
keywords = [oxy1, per1, dil1,dil2, tra1, tra2, cod1, fen1, dem1, dem2, met1, met2, big1, bla1, bro1, cha1, chi1, dor1, mex1, oxs1, pur1, tan1, wat1, whi1,vic1, adi1, keys1, keys2]
len(keywords)
# Out:
# 28

# %%
keywords_complete = [oxy, per, dil, tra, cod, fen, dem, met, big, bla, bro, cha, chi, dor, mex, oxs, pur, tan, wat, whi ,vic, adi, keys_1]

# %%
limit = 2000

tweets = tweepy.Cursor(api.search_tweets, q=pur1, count=100, tweet_mode='extended', lang="en", ).items(limit)
columns = ['User', 'Tweet']
data = []

for tweet in tweets:
    data.append([tweet.user.screen_name, tweet.full_text])

df = pd.DataFrame(data, columns=columns)
df
# Out:
# Empty DataFrame
# Columns: [User, Tweet]
# Index: []

# %%
tweets
# Out:
# 0

# %%
df.to_csv("tweet_data3.csv", index=False)

# %%
df.to_csv("tweets_new.csv", index=False)

# %%
df["Tweet"][0]
# Out:
# 'Not making light of a bad situation. But damn...I had shoulder surgery in mid-Sept. Some days better than others. I did too much yesterday...been in severe pain today. Saved a few oxycontin from surgery...and had one, and within minutes, feel GREAT. Get why people get addicted.'

# %%
df["Tweet"][499]
# Out:
# 'Oh great, another lame lunar eclipse. The meth-addicted trailer trash of the celestial world.'

# %%
df.head(50)
# Out:
#                User                                              Tweet
# 0        Bunnyhunee  Self aware hooker drug addict on a night out W...
# 1          ubertaak  I heard voices saying “meth addict” today when...
# 2      bluestoday22  Opioid withdrawal is no fun. See, I had surger...
# 3          ubertaak  “There’s a meth addict in 7A.” There aren’t an...
# 4        TizosJCIWA  Did you hear about the junkie that was addicte...
# 5     alyynoelle666  Do you absolutely love the band soundgarden? \...
# 6       monkhealing  New Episode! "Navigating Early Recovery and So...
# 7          ubertaak  They’ve been calling me a crystal meth addict....
# 8        justlilmeg  I was watching this YouTube about Amanda bynes...
# 9   matt_norris1973  I've just started following Rehab Addict Lake ...
# 10       dodicOMJMZ  Why did the duck go to rehab? Because he was a...
# 11        SLegros33  Through an Addict's Eyes: Options for Opiate A...
# ...

# %%
keyword4 = """Hydrocodone
Oxycodone
Oxycontin
Fentanyl
Heroin
Vicodin
Duragesic
H
Lortab
Percocet
Actiq
Smack
Lori
Oxycet
Sublimaze
Dope
Lorcet
Oxycotton
Apache
"China White"
Vike
"Hillbilly Heroin"
"China Girl"
Horse
Vees
Percs
"China White"
Skag
Watsons
O
"Dance Fever"
Junk
Vics
Ox
Goodfella
"Black Tar"
Hydros
Blues
Jackpot
"Big H"
Scratch
512s
"Murder 8"
"Brown Sugar"
Norco
Idiot pills
Tabs
357s
Dones
Droco
IP109
IP110
Zohydro
M367
Kickers
Killers
Oxy
Oxyclean
Roxy
Roxi
Oxynorm
A215
K8
Oxyneo
M15
M30
A15
OC30
OC80
OP80
M523
IP204
C230
V4812
CDN80
"Tango and Cash"
Tnt
"Dragon’s Breath"
Fenty
Fent
"King Ivory"
"White Girl"
Birria
Chyna
Acetylfentanyl
Phenaridine
Mud
Dragon
"Mexican Brown"
Thunder
Skunk
Big Harry
"Birdie Powder"
"Fairy Dust"
Chiva
Speedball
Pearl Tar
Diacetylmorphine
Gunpowder"""

# %%
keywords4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/cz/vjt5grr94cn0qr63v4qx4qth0000gn/T/ipykernel_46703/3015101102.py in <module>
# ----> 1 keywords4
#
# NameError: name 'keywords4' is not defined

# %%
keyword4d4 = """Hydrocodone
Oxycodone
Oxycontin
Fentanyl
Heroin
Vicodin
Duragesic
H
Lortab
Percocet
Actiq
Smack
Lori
Oxycet
Sublimaze
Dope
Lorcet
Oxycotton
Apache
"China White"
Vike
"Hillbilly Heroin"
"China Girl"
Horse
Vees
Percs
"China White"
Skag
Watsons
O
"Dance Fever"
Junk
Vics
Ox
Goodfella
"Black Tar"
Hydros
Blues
Jackpot
"Big H"
Scratch
512s
"Murder 8"
"Brown Sugar"
Norco
Idiot pills
Tabs
357s
Dones
Droco
IP109
IP110
Zohydro
M367
Kickers
Killers
Oxy
Oxyclean
Roxy
Roxi
Oxynorm
A215
K8
Oxyneo
M15
M30
A15
OC30
OC80
OP80
M523
IP204
C230
V4812
CDN80
"Tango and Cash"
Tnt
"Dragon’s Breath"
Fenty
Fent
"King Ivory"
"White Girl"
Birria
Chyna
Acetylfentanyl
Phenaridine
Mud
Dragon
"Mexican Brown"
Thunder
Skunk
Big Harry
"Birdie Powder"
"Fairy Dust"
Chiva
Speedball
Pearl Tar
Diacetylmorphine
Gunpowder"""
keywords4_list = keyword4.split("\n")
keywords4_list = [ i.lower().strip() for i in keywords4_list]
keywords4 = (" OR ".join(keywords4_list))

# %%
import numpy as np
keywords4_list = np.array(keywords4_list)

# %%
keywords8 = np.array_split(keywords4_list, 7)

# %%
keywords8
# Out:
# [array(['hydrocodone', 'oxycodone', 'oxycontin', 'fentanyl', 'heroin',
#         'vicodin', 'duragesic', 'h', 'lortab', 'percocet', 'actiq',
#         'smack', 'lori', 'oxycet', 'sublimaze'], dtype='<U18'),
#  array(['dope', 'lorcet', 'oxycotton', 'apache', '"china white"', 'vike',
#         '"hillbilly heroin"', '"china girl"', 'horse', 'vees', 'percs',
#         '"china white"', 'skag', 'watsons'], dtype='<U18'),
#  array(['o', '"dance fever"', 'junk', 'vics', 'ox', 'goodfella',
#         '"black tar"', 'hydros', 'blues', 'jackpot', '"big h"', 'scratch',
#         '512s', '"murder 8"'], dtype='<U18'),
#  array(['"brown sugar"', 'norco', 'idiot pills', 'tabs', '357s', 'dones',
#         'droco', 'ip109', 'ip110', 'zohydro', 'm367', 'kickers', 'killers',
#         'oxy'], dtype='<U18'),
#  array(['oxyclean', 'roxy', 'roxi', 'oxynorm', 'a215', 'k8', 'oxyneo',
#         'm15', 'm30', 'a15', 'oc30', 'oc80', 'op80', 'm523'], dtype='<U18'),
# ...

# %%
keywords8 = [" OR ".join(keywords8[i]) for i in range(0, len(keywords8)-1)]
keywords8
# Out:
# ['hydrocodone OR oxycodone OR oxycontin OR fentanyl OR heroin OR vicodin OR duragesic OR h OR lortab OR percocet OR actiq OR smack OR lori OR oxycet OR sublimaze',
#  'dope OR lorcet OR oxycotton OR apache OR "china white" OR vike OR "hillbilly heroin" OR "china girl" OR horse OR vees OR percs OR "china white" OR skag OR watsons',
#  'o OR "dance fever" OR junk OR vics OR ox OR goodfella OR "black tar" OR hydros OR blues OR jackpot OR "big h" OR scratch OR 512s OR "murder 8"',
#  '"brown sugar" OR norco OR idiot pills OR tabs OR 357s OR dones OR droco OR ip109 OR ip110 OR zohydro OR m367 OR kickers OR killers OR oxy',
#  'oxyclean OR roxy OR roxi OR oxynorm OR a215 OR k8 OR oxyneo OR m15 OR m30 OR a15 OR oc30 OR oc80 OR op80 OR m523',
#  'ip204 OR c230 OR v4812 OR cdn80 OR "tango and cash" OR tnt OR "dragon’s breath" OR fenty OR fent OR "king ivory" OR "white girl" OR birria OR chyna OR acetylfentanyl']

# %%
opioids[:5]
# Out:
# ['(oxycontin OR oxicontin OR oxcotin OR oycotin OR oxycotins OR oycontin OR oxycontins OR oxycoton OR oxicotin) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose) -RT exclude:mentions exclude:replies -has:links',
#  '(ocycotin OR oxycodin OR oxycottin OR oxycotine OR ocycontin OR oxycintin OR oycotine OR oxcycontin OR roxicontin) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose) -RT exclude:mentions exclude:replies -has:links',
#  '(oxycotin OR oxycontine OR roxycontin OR oxycotton OR oxycottin OR oxycoton OR percocet OR percocet10 OR perocets) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose) -RT exclude:mentions exclude:replies -has:links',
# ...

# %%
opioids[4]
# Out:
# '(pecocets OR percoet OR percocit OR percocoet OR percot OR percoset OR percecet OR percicet OR dilaudid) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose) -RT exclude:mentions exclude:replies -has:links'

# %%
# search tweetss
limit=500
dfs = []

tweets = tweepy.Cursor(api.search_tweets, q="(pecocets OR percoet OR percocit OR percocoet OR percot OR percoset OR percecet OR percicet OR dilaudid) (sober OR withdrawal OR addicted OR addict OR use OR using OR withdraw OR medication OR overdose)", count=100, tweet_mode='extended', lang="en").items(limit)
columns = ['User', 'Tweet']
data = []

for tweet in tweets:
    data.append([tweet.user.screen_name, tweet.full_text])

df = pd.DataFrame(data, columns=columns)
df

# tweets = api.user_timeline(screen_name=user, count=limit, tweet_mode='extended')

# create DataFrame

# frames = pd.concat(dfs,
#                    join="outer",
#                    ignore_index=True)

# frames
# Out:
#               User  \
# 0    mike24forever
# 1        DrStegall
# 2  TeddiThompsonS1
#
#                                                                                                                                                                                                                                                                                                                 Tweet
# 0  @GovCanHealth This is bullshit. I’ve been on Dilaudid (sp?) for 11 years after being paralyzed in a hit &amp; run. I still have chronic back pain &amp; nerve pain My pain doctor &amp; I had it under control. UNTIL THE GOV. DECIDED THAT I SHOULD NO LONGER BE ON IT. So now I’m in pain. No withdrawal though.
# ...

# %%
keywords = "fentanyl, oxycontin, opioid, oxycodone, oxy, vicodin, hydromorphone, hydrocodone, morphine, methadone, percocet, codeine, heroin tylenol 3, percs, codein cough syrup, drinking lean, overdose, naloxone, misuse, medication, addicted"
keywords = keywords.split(",")
keywords = [i.strip() for i in keywords]
keywords = " OR ".join(keywords)
keywords = 'fentanyl OR oxycontin OR opioid OR oxycodone OR oxy OR vicodin OR hydromorphone OR hydrocodone OR morphine OR methadone OR percocet OR codeine OR heroin tylenol 3 OR percs OR codein cough syrup OR drinking lean OR overdose OR naloxone (misuse OR medication OR addicted)'

# %%
# search tweetss
limit=200
dfs = []

for i in opioids:
    tweets = tweepy.Cursor(api.search_tweets, q=i, count=100, tweet_mode='extended', lang="en", until="2020-07-19").items(limit)
    columns = ['User', 'Tweet']
    data = []

    for tweet in tweets:
        data.append([tweet.user.screen_name, tweet.full_text])

    df = pd.DataFrame(data, columns=columns)
    dfs.append(df)

# tweets = api.user_timeline(screen_name=user, count=limit, tweet_mode='extended')

# create DataFrame

frames = pd.concat(dfs,
                   join="outer",
                   ignore_index=True)

frames
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /var/folders/cz/vjt5grr94cn0qr63v4qx4qth0000gn/T/ipykernel_14494/2042862591.py in <module>
#       8     data = []
#       9
# ---> 10     for tweet in tweets:
#      11         data.append([tweet.user.screen_name, tweet.full_text])
#      12
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
#     287             while len(self.current_page) == 0:
# ...

# %%
frames.to_csv("tweets6.csv", index=False)

# %%
# search tweets
limit=400
dfs = []

for i in keywords:
    tweets = tweepy.Cursor(api.search_tweets, q=vic1, count=100, tweet_mode='extended', lang="en").items(limit)
    columns = ['User', 'Tweet']
    data = []

    for tweet in tweets:
        data.append([tweet.user.screen_name, tweet.full_text])

    df = pd.DataFrame(data, columns=columns)
    dfs.append(df)

# tweets = api.user_timeline(screen_name=user, count=limit, tweet_mode='extended')

# create DataFrame

frames = pd.concat(dfs,
                   join="outer",
                   ignore_index=True)

frames
# Out:
#                User  \
# 0          mone_oxy
# 1      Cryptop12789
# 2        dounrugged
# 3          dirtyP30
# 4      Path_Trading
# ...             ...
# 2795  CryptoNews_21
# 2796        oxy_nat
# 2797  LuredoMarbery
# 2798     eylexiis21
# 2799  Djpowerline29
#
#                                                                                                                                                                                                                                                                                                              Tweet
# 0                                                                                                                                                                                   I think it’s so sad when people are use to being gone wrong .. they no longer take chances. That use to be me but not anymore.
# ...

# %%
frames
# Out:
# Empty DataFrame
# Columns: [User, Tweet]
# Index: []

# %%
frames.to_csv("twitter_data_2.csv", index=False)

# %%
reviewed_tweets = pd.read_csv("csc_867_twitter_scraping - reviewed_good_data.csv")

# %%
reviewed_tweets
# Out:
#               User  \
# 0    danieledobish
# 1      lilchopstik
# 2      NoonSoldier
# 3         Flip_J10
# 4      TrvpMoneyZo
# ..             ...
# 168    SleepySamFL
# 169       recs2k21
# 170     resedajohn
# 171       beimir20
# 172       cubikles
#
#                                                                                                                                                                                                                                                                                                                                 Tweet  \
# 0                                              Not making light of a bad situation. But damn...I had shoulder surgery in mid-Sept. Some days better than others. I did too much yesterday...been in severe pain today. Saved a few oxycontin from surgery...and had one, and within minutes, feel GREAT. Get why people get addicted.
# ...

# %%
reviewed_tweets.reset_index(inplace=True, drop=True)

# %%
reviewed_tweets.iloc[80]
# Out:
# User                                                                                     SpecialKSkyhook
# Tweet    OXYCODONE IS THE BEST DRUG OF ALL TIME IF THEY JUST LEGALIZED IT HEROIN WOULD VANISH OVER NIGHT
# Label                                                                                            Present
# Name: 80, dtype: object

# %%
tweets = tweepy.Cursor(api.user_timeline, screen_name="Expect_theworst", count=200, tweet_mode='extended').items(limit)

# %%
reviewed_tweets
# Out:
#               User  \
# 0    danieledobish
# 1      lilchopstik
# 2      NoonSoldier
# 3         Flip_J10
# 4      TrvpMoneyZo
# ..             ...
# 167    SleepySamFL
# 168       recs2k21
# 169     resedajohn
# 170       beimir20
# 171       cubikles
#
#                                                                                                                                                                                                                                                                                                                                 Tweet  \
# 0                                              Not making light of a bad situation. But damn...I had shoulder surgery in mid-Sept. Some days better than others. I did too much yesterday...been in severe pain today. Saved a few oxycontin from surgery...and had one, and within minutes, feel GREAT. Get why people get addicted.
# ...

# %%
#Retrieving tweets by user
user_tweets = []


limit = 10
for user in reviewed_tweets["User"]:
    tweets = tweepy.Cursor(api.search_tweets, q="from:"+user, count=200, tweet_mode='extended').items(limit)
    columns = ['User', 'Tweet']
    data = []

    print(user)

    try:
        for tweet in tweets:
            data.append([tweet.user.screen_name, tweet.full_text])
    except:
        print("Didn't work")
        continue


    df = pd.DataFrame(data, columns=columns)
    user_tweets.append(df)
# Out:
# danieledobish
# lilchopstik
# NoonSoldier
# Flip_J10
# TrvpMoneyZo
# amy2ree
# baIIjointedoII
# complete_tripe
# Didn't work
# EndingFinsta
# Didn't work
# Nobody54751855
# Didn't work
# leirexic
# Didn't work
# NicoQuattromini
# Didn't work
# kit_delgadoMD
# Didn't work
# Jessica_Midder
# Didn't work
# Bunnyhunee
# Didn't work
# lorennaalmeida_
# Didn't work
# Daniipacini
# Didn't work
# deyjandiulfur
# Didn't work
# TahohPYWFA
# Didn't work
# CorbinDollas
# Didn't work
# NunozUBIZJ
# Didn't work
# brainscramblies
# Didn't work
# itg1rlgigi
# Didn't work
# luh_vhet
# Didn't work
# DaFiretruck
# Didn't work
# GriseldaBLACCo
# Didn't work
# JUGGHarden
# Didn't work
# tarahsephorah
# Didn't work
# jkdanaee
# Didn't work
# SkateboardP_12
# Didn't work
# ddemolitionluvr
# Didn't work
# mbox30_
# Didn't work
# slowboogiewalt
# Didn't work
# kappalottttt
# Didn't work
# LessThanDaniyal
# Didn't work
# fruutzies
# Didn't work
# MaryBethO_
# Didn't work
# ari3lm
# Didn't work
# Trevor_S7_
# ...

# %%
user_tweet_frames = pd.concat(user_tweets,
                   join="outer",
                   ignore_index=True)

# %%
user_tweet_frames
# Out:
#               User  \
# 0    danieledobish
# 1    danieledobish
# 2    danieledobish
# 3    danieledobish
# 4    danieledobish
# ..             ...
# 65  baIIjointedoII
# 66  baIIjointedoII
# 67  baIIjointedoII
# 68  baIIjointedoII
# 69  baIIjointedoII
#
#                                                                                                                                                                                                                                                                                       Tweet
# 0                                                                                                                                    More on Pac-12 woes on the hardwood...\n\nGrambling (+14.5, ML +800) upended Colorado 83-74 earlier. Cal, Stanford also lost as slight underdogs. #CBK
# ...

# %%
user_tweet_frames.to_csv("tweets_data4_repeateduser.csv", index=False)

# %%
#Retrieving tweets by user
user_tweets = []


limit = 20
for user in reviewed_tweets["User"]:
    tweets = tweepy.Cursor(api.user_timeline, screen_name=user, count=200, tweet_mode='extended').items(limit)
    columns = ['User', 'Tweet']
    data = []
    
    print(user)
    
    try:
        for tweet in tweets:
            data.append([tweet.user.screen_name, tweet.full_text])
    except:
        continue
  
    
    df = pd.DataFrame(data, columns=columns)
    user_tweets.append(df)
# Out:
# danieledobish
# lilchopstik
# NoonSoldier
# Flip_J10
# TrvpMoneyZo
# amy2ree
# baIIjointedoII
# complete_tripe
# EndingFinsta
# Nobody54751855
# leirexic
# NicoQuattromini
# kit_delgadoMD
# Jessica_Midder
# Bunnyhunee
# lorennaalmeida_
# Daniipacini
# deyjandiulfur
# TahohPYWFA
# CorbinDollas
# NunozUBIZJ
# brainscramblies
# itg1rlgigi
# luh_vhet
# DaFiretruck
# GriseldaBLACCo
# JUGGHarden
# tarahsephorah
# jkdanaee
# SkateboardP_12
# ddemolitionluvr
# mbox30_
# slowboogiewalt
# kappalottttt
# LessThanDaniyal
# fruutzies
# MaryBethO_
# ari3lm
# Trevor_S7_
# FriendlyCatWife
# Osborneosaurus
# yungrowdyboy
# KaKaSon365
# BitchImRee
# swirliezz
# Forever_Doped
# 4thegangrasta
# YFN_Flop
# berksstnana
# not_ioN_plant
# filthybuxks
# _wodie_
# _RealHancock
# KvngMgb
# DRZ4E52
# _Mikeyy_B
# T_raayy
# ViolenceCDQ_
# longlivenedo
# anndrefer
# dmt4dmt
# arrjayteatoo
# ratlesbiann
# ____pKayy
# JJ_BAU
# Jellaaaay
# _timchevalier_
# dulaudid
# ree_sodope
# TownOfFergus
# King_Blacq
# ...

# %%
user_tweet_frames = pd.concat(user_tweets,
                   join="outer",
                   ignore_index=True)

# %%
user_tweet_frames
# Out:
#                User  \
# 0     danieledobish
# 1     danieledobish
# 2     danieledobish
# 3     danieledobish
# 4     danieledobish
# ...             ...
# 3312       cubikles
# 3313       cubikles
# 3314       cubikles
# 3315       cubikles
# 3316       cubikles
#
#                                                                                                                                                                                                                                                                                                    Tweet
# 0                                                                                                                                                 More on Pac-12 woes on the hardwood...\n\nGrambling (+14.5, ML +800) upended Colorado 83-74 earlier. Cal, Stanford also lost as slight underdogs. #CBK
# ...

# %%
user_tweet_frames.to_csv("tweet_data5.csv", index=False)
